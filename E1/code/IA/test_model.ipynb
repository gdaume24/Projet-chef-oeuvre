# %%
import sys
import pandas as pd
import pickle
import inspect
import os
from import_data_from_bdd import charger_donnees

df = charger_donnees(r"C:\Users\daumer-g\Desktop\vscode\Projet-chef-d-oeuvre\E1\code\bdd_sqlite_entrainement\db.db")
df.head()
# Out:
# Le jeu de donnée a été chargé à partir de la base de données.
#    Age  Gender self_employed family_history treatment work_interfere  \
# 0   37  Female         Other             No       Yes          Often
# 1   44    Male         Other             No        No         Rarely
# 2   32    Male         Other             No        No         Rarely
# 3   31    Male         Other            Yes       Yes          Often
# 4   31    Male         Other             No        No          Never
#
#      no_employees remote_work tech_company    benefits  ...  \
# 0            6-25          No          Yes         Yes  ...
# 1  More than 1000          No           No  Don't know  ...
# 2            6-25          No          Yes          No  ...
# 3          26-100          No          Yes          No  ...
# 4         100-500         Yes          Yes         Yes  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
input_df = pd.DataFrame(input_data_dict, index=[0])
model.predict(input_df)[0]
# Out:
# 'No'
